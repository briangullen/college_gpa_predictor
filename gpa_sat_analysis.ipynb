# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('sat_gpa_v1.csv')

# %%
df.head()
# Out:
#    sat_sum  fy_gpa
# 0     1270    3.18
# 1     1220    3.33
# 2     1160    3.25
# 3      950    2.42
# 4     1070    2.63

# %%
sns.lmplot(data=df, x='sat_sum', y='fy_gpa').set(title='Comparison of SAT Score vs GPA', xlabel='SAT', ylabel='GPA')

# %%
X = df.drop('fy_gpa', axis=1)
y = df.fy_gpa
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=12)

# %%
lr = LinearRegression()
lr.fit(X=X_train, y=y_train)
# Out:
# LinearRegression()

# %%
r2_score(y_true=y_test, y_pred=lr.predict(X_test))
# Out:
# 0.20768268049825234

# %% [markdown]
# ### Interpretation
#
# The "r2_score" (R2 coefficient) has a best possible score of 1.0. The score of using SAT to predict GPA has an r2_score of 0.207 which indicates a weak relationship. Given this score it should be interpreted that SAT scores are not a good predicator of GPA.
